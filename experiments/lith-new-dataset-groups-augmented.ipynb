# %%
import os
from datetime import datetime
from multitask_trainer import train_eval_model

# %% [markdown]
# ## E5+LoRa

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"
model_path = "intfloat/multilingual-e5-large"
cache_dir = '../cache'

def get_experiment_config(input_model_name):
    return [
        ("../augmentation/augmented_data_2/lith_dataset_augmented_groups_full", f"outputs/lith_classifier_{input_model_name}_lora_grouped_augmented")
    ]

exp_config = get_experiment_config("e5")
lora_args = {
    "init_lora_weights": "olora",
    "target_modules": "all-linear"
}
batch_size = 32

# %%
print("Training started:", datetime.now())
# Out:
# Training started: 2026-05-15 21:34:42.829664

# %%
for data_dir, model_dir in exp_config:
    print(f"Training E5 classifier for data {data_dir}")
    _, results = train_eval_model(model_path, data_dir, cache_dir=cache_dir, save_model_dir=model_dir, 
                                  batch_size=batch_size, num_epochs=20, eval_batch_size=128, 
                                  use_lora=True, lora_args=lora_args)
    print(results)
# Out:
# Training E5 classifier for data ../augmentation/augmented_data_2/lith_dataset_augmented_groups_full
# Some weights of BertMultiTaskClassifier were not initialized from the model checkpoint at intfloat/multilingual-e5-large and are newly initialized: ['heads.0.1.bias', 'heads.0.1.weight', 'heads.1.1.bias', 'heads.1.1.weight', 'heads.2.1.bias', 'heads.2.1.weight', 'heads.3.1.bias', 'heads.3.1.weight', 'heads.4.1.bias', 'heads.4.1.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 17,268
#   Num Epochs = 20
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10,800
#   Number of trainable parameters = 3,565,588
#     <div>
#
#       <progress value='10800' max='10800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10800/10800 2:34:06, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Score</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Roc Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.252300</td>
#       <td>0.463851</td>
#       <td>0.850953</td>
#       <td>0.863560</td>
#       <td>0.797906</td>
#       <td>0.941576</td>
#       <td>0.850863</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.359900</td>
#       <td>0.461718</td>
#       <td>0.851976</td>
#       <td>0.867693</td>
#       <td>0.787223</td>
#       <td>0.967585</td>
#       <td>0.851876</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.127800</td>
#       <td>0.392981</td>
#       <td>0.882200</td>
#       <td>0.886243</td>
#       <td>0.854514</td>
#       <td>0.924423</td>
#       <td>0.882134</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.982700</td>
#       <td>0.349055</td>
#       <td>0.895639</td>
#       <td>0.900800</td>
#       <td>0.859148</td>
#       <td>0.948176</td>
#       <td>0.895593</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.882800</td>
#       <td>0.351629</td>
#       <td>0.899659</td>
#       <td>0.905310</td>
#       <td>0.859698</td>
#       <td>0.956549</td>
#       <td>0.899594</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.771200</td>
#       <td>0.334223</td>
#       <td>0.910659</td>
#       <td>0.914327</td>
#       <td>0.879189</td>
#       <td>0.953323</td>
#       <td>0.910594</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.657600</td>
#       <td>0.356312</td>
#       <td>0.903116</td>
#       <td>0.907483</td>
#       <td>0.870020</td>
#       <td>0.948525</td>
#       <td>0.903078</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.581300</td>
#       <td>0.431139</td>
#       <td>0.902720</td>
#       <td>0.908761</td>
#       <td>0.860485</td>
#       <td>0.963969</td>
#       <td>0.902655</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.526300</td>
#       <td>0.360482</td>
#       <td>0.908645</td>
#       <td>0.913306</td>
#       <td>0.869957</td>
#       <td>0.961489</td>
#       <td>0.908580</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.476100</td>
#       <td>0.328162</td>
#       <td>0.912164</td>
#       <td>0.910840</td>
#       <td>0.920813</td>
#       <td>0.902566</td>
#       <td>0.912145</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.404600</td>
#       <td>0.372078</td>
#       <td>0.914933</td>
#       <td>0.918048</td>
#       <td>0.888622</td>
#       <td>0.950486</td>
#       <td>0.914883</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.359300</td>
#       <td>0.384404</td>
#       <td>0.918840</td>
#       <td>0.922447</td>
#       <td>0.888099</td>
#       <td>0.960104</td>
#       <td>0.918824</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.308400</td>
#       <td>0.424770</td>
#       <td>0.919957</td>
#       <td>0.922825</td>
#       <td>0.893935</td>
#       <td>0.954209</td>
#       <td>0.919926</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.287300</td>
#       <td>0.428899</td>
#       <td>0.917722</td>
#       <td>0.920981</td>
#       <td>0.887477</td>
#       <td>0.957480</td>
#       <td>0.917682</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.250100</td>
#       <td>0.395588</td>
#       <td>0.924820</td>
#       <td>0.927394</td>
#       <td>0.898736</td>
#       <td>0.958240</td>
#       <td>0.924787</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.232600</td>
#       <td>0.469717</td>
#       <td>0.923801</td>
#       <td>0.926685</td>
#       <td>0.894079</td>
#       <td>0.961991</td>
#       <td>0.923762</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.211200</td>
#       <td>0.515942</td>
#       <td>0.918644</td>
#       <td>0.921009</td>
#       <td>0.895286</td>
#       <td>0.948514</td>
#       <td>0.918603</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.154600</td>
#       <td>0.605633</td>
#       <td>0.913061</td>
#       <td>0.917611</td>
#       <td>0.874412</td>
#       <td>0.965657</td>
#       <td>0.913011</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.138300</td>
#       <td>0.521888</td>
#       <td>0.926906</td>
#       <td>0.929498</td>
#       <td>0.898051</td>
#       <td>0.963435</td>
#       <td>0.926866</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.127400</td>
#       <td>0.540000</td>
#       <td>0.924947</td>
#       <td>0.927526</td>
#       <td>0.897590</td>
#       <td>0.959787</td>
#       <td>0.924910</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-540
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-2548] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-1080
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-4368] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-1620
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-540] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-2160
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-1080] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-2700
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-1620] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-3240
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-2160] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-3780
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-2700] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-4320
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-3780] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-4860
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-4320] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-5400
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-3240] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-5940
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-4860] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-6480
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-5400] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-7020
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-5940] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-7560
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-6480] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-8100
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-7020] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-8640
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-7560] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-9180
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-8640] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-9720
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-9180] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-10260
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-8100] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-10800
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-9720] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from test-classifier/checkpoint-10260 (score: 0.9269057764864422).
#
# ***** Running Prediction *****
#   Num examples = 2642
#   Batch size = 128
# sexuality
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95       185
#            1       0.93      0.98      0.95       184
#
#     accuracy                           0.95       369
#    macro avg       0.95      0.95      0.95       369
# weighted avg       0.96      0.95      0.95       369
#
# religion
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.91       183
#            1       0.88      0.96      0.91       183
#
#     accuracy                           0.91       366
#    macro avg       0.91      0.91      0.91       366
# weighted avg       0.91      0.91      0.91       366
#
# country
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93        93
#            1       0.90      0.97      0.93        94
#
#     accuracy                           0.93       187
#    macro avg       0.93      0.93      0.93       187
# weighted avg       0.93      0.93      0.93       187
#
# race
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       360
#            1       0.88      0.96      0.92       361
#
#     accuracy                           0.92       721
#    macro avg       0.92      0.92      0.92       721
# weighted avg       0.92      0.92      0.92       721
#
# politics
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       500
#            1       0.90      0.96      0.93       499
#
#     accuracy                           0.92       999
#    macro avg       0.93      0.92      0.92       999
# weighted avg       0.93      0.92      0.92       999
# tokenizer config file saved in outputs/lith_classifier_e5_lora_grouped_augmented/tokenizer_config.json
# Special tokens file saved in outputs/lith_classifier_e5_lora_grouped_augmented/special_tokens_map.json
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--intfloat--multilingual-e5-large/snapshots/3d7cfbdacd47fdda877c5cd8a79fbcc4f2a574f3/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#         task  accuracy  f1_score  precision    recall     kappa   roc_auc
# 0  sexuality  0.953930  0.954907   0.932642  0.978261  0.907871  0.953995
# 1   religion  0.909836  0.913838   0.875000  0.956284  0.819672  0.909836
# 2    country  0.930481  0.933333   0.900990  0.968085  0.860903  0.930279
# 3       race  0.916782  0.920424   0.882952  0.961219  0.833544  0.916721
# 4   politics  0.923924  0.926357   0.896811  0.957916  0.847858  0.923958

# %%
print("Training finished:", datetime.now())
# Out:
# Training finished: 2026-05-16 00:09:29.889327

# %% [markdown]
# ## LaBSE+Lora

# %%
model_path = "sentence-transformers/LaBSE"
exp_config = get_experiment_config("labse")

# %%
for data_dir, model_dir in exp_config:
    print(f"Training LaBSE classifier for data {data_dir}")
    _, results = train_eval_model(model_path, data_dir, cache_dir=cache_dir, save_model_dir=model_dir, 
                                  batch_size=batch_size, num_epochs=20, eval_batch_size=128, 
                                  use_lora=True, lora_args=lora_args)
    print(results)
# Out:
# Training LaBSE classifier for data ../augmentation/augmented_data_2/lith_dataset_augmented_groups_full
# loading configuration file config.json from cache at ../cache/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# loading file vocab.txt from cache at ../cache/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/vocab.txt
# loading file tokenizer.json from cache at ../cache/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at ../cache/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/special_tokens_map.json
# loading file tokenizer_config.json from cache at ../cache/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/tokenizer_config.json
# loading file chat_template.jinja from cache at None
# loading configuration file config.json from cache at ../cache/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# loading configuration file config.json from cache at ../cache/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# loading weights file model.safetensors from cache at ../cache/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/model.safetensors
# All model checkpoint weights were used when initializing BertMultiTaskClassifier.
#
# Some weights of BertMultiTaskClassifier were not initialized from the model checkpoint at sentence-transformers/LaBSE and are newly initialized: ['heads.0.1.bias', 'heads.0.1.weight', 'heads.1.1.bias', 'heads.1.1.weight', 'heads.2.1.bias', 'heads.2.1.weight', 'heads.3.1.bias', 'heads.3.1.weight', 'heads.4.1.bias', 'heads.4.1.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# average_tokens_across_devices is True but world size is 1. Setting it to False automatically.
# ***** Running training *****
#   Num examples = 17,268
#   Num Epochs = 20
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10,800
#   Number of trainable parameters = 1,347,092
#     <div>
#
#       <progress value='10800' max='10800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10800/10800 54:08, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Score</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Roc Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.206000</td>
#       <td>0.493216</td>
#       <td>0.822173</td>
#       <td>0.833524</td>
#       <td>0.785990</td>
#       <td>0.888083</td>
#       <td>0.822095</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.412200</td>
#       <td>0.422452</td>
#       <td>0.857291</td>
#       <td>0.868018</td>
#       <td>0.808376</td>
#       <td>0.938320</td>
#       <td>0.857205</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.142300</td>
#       <td>0.364766</td>
#       <td>0.886629</td>
#       <td>0.893247</td>
#       <td>0.846076</td>
#       <td>0.947561</td>
#       <td>0.886555</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.947100</td>
#       <td>0.333336</td>
#       <td>0.898348</td>
#       <td>0.901263</td>
#       <td>0.878265</td>
#       <td>0.926761</td>
#       <td>0.898327</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.832100</td>
#       <td>0.321123</td>
#       <td>0.903565</td>
#       <td>0.902986</td>
#       <td>0.899591</td>
#       <td>0.909197</td>
#       <td>0.903514</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.725300</td>
#       <td>0.306725</td>
#       <td>0.909304</td>
#       <td>0.910781</td>
#       <td>0.891564</td>
#       <td>0.931677</td>
#       <td>0.909256</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.626400</td>
#       <td>0.317121</td>
#       <td>0.909211</td>
#       <td>0.910334</td>
#       <td>0.896712</td>
#       <td>0.924923</td>
#       <td>0.909182</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.555600</td>
#       <td>0.323453</td>
#       <td>0.909767</td>
#       <td>0.913801</td>
#       <td>0.874726</td>
#       <td>0.956940</td>
#       <td>0.909714</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.496000</td>
#       <td>0.379800</td>
#       <td>0.902270</td>
#       <td>0.908129</td>
#       <td>0.858195</td>
#       <td>0.964492</td>
#       <td>0.902201</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.465600</td>
#       <td>0.331366</td>
#       <td>0.913430</td>
#       <td>0.913867</td>
#       <td>0.908886</td>
#       <td>0.918959</td>
#       <td>0.913416</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.381700</td>
#       <td>0.337896</td>
#       <td>0.920096</td>
#       <td>0.922113</td>
#       <td>0.899098</td>
#       <td>0.946521</td>
#       <td>0.920056</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.337800</td>
#       <td>0.416947</td>
#       <td>0.906768</td>
#       <td>0.911957</td>
#       <td>0.867745</td>
#       <td>0.961395</td>
#       <td>0.906725</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.326200</td>
#       <td>0.368051</td>
#       <td>0.919185</td>
#       <td>0.921652</td>
#       <td>0.896551</td>
#       <td>0.948551</td>
#       <td>0.919147</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.312400</td>
#       <td>0.386849</td>
#       <td>0.918089</td>
#       <td>0.920510</td>
#       <td>0.896529</td>
#       <td>0.946044</td>
#       <td>0.918058</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.270000</td>
#       <td>0.381982</td>
#       <td>0.924598</td>
#       <td>0.926056</td>
#       <td>0.909537</td>
#       <td>0.943381</td>
#       <td>0.924571</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.227800</td>
#       <td>0.421428</td>
#       <td>0.916902</td>
#       <td>0.919841</td>
#       <td>0.890842</td>
#       <td>0.951167</td>
#       <td>0.916861</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.231900</td>
#       <td>0.434225</td>
#       <td>0.917810</td>
#       <td>0.920313</td>
#       <td>0.894421</td>
#       <td>0.948061</td>
#       <td>0.917770</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.218700</td>
#       <td>0.429749</td>
#       <td>0.919878</td>
#       <td>0.922350</td>
#       <td>0.896604</td>
#       <td>0.949829</td>
#       <td>0.919843</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.206600</td>
#       <td>0.425564</td>
#       <td>0.923726</td>
#       <td>0.925472</td>
#       <td>0.905723</td>
#       <td>0.946407</td>
#       <td>0.923690</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.184700</td>
#       <td>0.423127</td>
#       <td>0.921954</td>
#       <td>0.923842</td>
#       <td>0.902757</td>
#       <td>0.946168</td>
#       <td>0.921919</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-540
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-10260] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-1080
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-10800] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-1620
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-540] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-2160
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-1080] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-2700
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-1620] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-3240
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-2160] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-3780
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-2700] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-4320
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-3240] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-4860
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-3780] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-5400
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-4320] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-5940
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-4860] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-6480
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-5400] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-7020
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-6480] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-7560
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-7020] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-8100
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-5940] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-8640
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-7560] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-9180
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-8640] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-9720
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-9180] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-10260
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-9720] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to test-classifier/checkpoint-10800
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#
# Deleting older checkpoint [test-classifier/checkpoint-10260] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from test-classifier/checkpoint-8100 (score: 0.9245976852245912).
#
# ***** Running Prediction *****
#   Num examples = 2642
#   Batch size = 128
# tokenizer config file saved in outputs/lith_classifier_labse_lora_grouped_augmented/tokenizer_config.json
# sexuality
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       185
#            1       0.96      0.95      0.95       184
#
#     accuracy                           0.95       369
#    macro avg       0.95      0.95      0.95       369
# weighted avg       0.95      0.95      0.95       369
#
# religion
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91       183
#            1       0.88      0.96      0.92       183
#
#     accuracy                           0.91       366
#    macro avg       0.92      0.91      0.91       366
# weighted avg       0.92      0.91      0.91       366
#
# country
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93        93
#            1       0.92      0.96      0.94        94
#
#     accuracy                           0.94       187
#    macro avg       0.94      0.94      0.94       187
# weighted avg       0.94      0.94      0.94       187
#
# race
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       360
#            1       0.89      0.91      0.90       361
#
#     accuracy                           0.90       721
#    macro avg       0.90      0.90      0.90       721
# weighted avg       0.90      0.90      0.90       721
#
# politics
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       500
#            1       0.88      0.93      0.90       499
#
#     accuracy                           0.90       999
#    macro avg       0.90      0.90      0.90       999
# weighted avg       0.90      0.90      0.90       999
# Special tokens file saved in outputs/lith_classifier_labse_lora_grouped_augmented/special_tokens_map.json
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--sentence-transformers--LaBSE/snapshots/836121a0533e5664b21c7aacc5d22951f2b8b25b/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 501153
# }
#         task  accuracy  f1_score  precision    recall     kappa   roc_auc
# 0  sexuality  0.953930  0.953678   0.956284  0.951087  0.907857  0.953922
# 1   religion  0.912568  0.916230   0.879397  0.956284  0.825137  0.912568
# 2    country  0.935829  0.937500   0.918367  0.957447  0.871625  0.935713
# 3       race  0.902913  0.904110   0.894309  0.914127  0.805819  0.902897
# 4   politics  0.901902  0.904297   0.881905  0.927856  0.803814  0.901928

# %% [markdown]
# ## LitLatBERT + LORA

# %%
model_path = "EMBEDDIA/litlat-bert"
exp_config = get_experiment_config("litlatbert")

# %%
print("Training started:", datetime.now())
# Out:
# Training started: 2026-05-16 01:03:54.871854

# %%
for data_dir, model_dir in exp_config:
    print(f"Training LiLatBERT classifier for data {data_dir}")
    _, results = train_eval_model(model_path, data_dir, cache_dir=cache_dir, save_model_dir=model_dir, 
                                  output_dir="outputs-train/litlatbert-lora-large",
                                  batch_size=batch_size, num_epochs=20, eval_batch_size=128, 
                                  tokenizer_args=dict(padding='max_length', truncation=True, max_length=512),
                                  use_lora=True, lora_args=lora_args)
    print(results)
# Out:
# Training LiLatBERT classifier for data ../augmentation/augmented_data_2/lith_dataset_augmented_groups_full
# loading configuration file config.json from cache at ../cache/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# loading file sentencepiece.bpe.model from cache at ../cache/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/sentencepiece.bpe.model
# loading file tokenizer.json from cache at ../cache/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at ../cache/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/special_tokens_map.json
# loading file tokenizer_config.json from cache at ../cache/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/tokenizer_config.json
# loading file chat_template.jinja from cache at None
# loading configuration file config.json from cache at ../cache/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# loading configuration file config.json from cache at ../cache/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# loading weights file pytorch_model.bin from cache at ../cache/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/pytorch_model.bin
# Attempting to create safetensors variant
# Safetensors PR exists
# Some weights of the model checkpoint at EMBEDDIA/litlat-bert were not used when initializing BertMultiTaskClassifier: ['lm_head.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'roberta.embeddings.LayerNorm.bias', 'roberta.embeddings.LayerNorm.weight', 'roberta.embeddings.position_embeddings.weight', 'roberta.embeddings.token_type_embeddings.weight', 'roberta.embeddings.word_embeddings.weight', 'roberta.encoder.layer.0.attention.output.LayerNorm.bias', 'roberta.encoder.layer.0.attention.output.LayerNorm.weight', 'roberta.encoder.layer.0.attention.output.dense.bias', 'roberta.encoder.layer.0.attention.output.dense.weight', 'roberta.encoder.layer.0.attention.self.key.bias', 'roberta.encoder.layer.0.attention.self.key.weight', 'roberta.encoder.layer.0.attention.self.query.bias', 'roberta.encoder.layer.0.attention.self.query.weight', 'roberta.encoder.layer.0.attention.self.value.bias', 'roberta.encoder.layer.0.attention.self.value.weight', 'roberta.encoder.layer.0.intermediate.dense.bias', 'roberta.encoder.layer.0.intermediate.dense.weight', 'roberta.encoder.layer.0.output.LayerNorm.bias', 'roberta.encoder.layer.0.output.LayerNorm.weight', 'roberta.encoder.layer.0.output.dense.bias', 'roberta.encoder.layer.0.output.dense.weight', 'roberta.encoder.layer.1.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.output.LayerNorm.weight', 'roberta.encoder.layer.1.attention.output.dense.bias', 'roberta.encoder.layer.1.attention.output.dense.weight', 'roberta.encoder.layer.1.attention.self.key.bias', 'roberta.encoder.layer.1.attention.self.key.weight', 'roberta.encoder.layer.1.attention.self.query.bias', 'roberta.encoder.layer.1.attention.self.query.weight', 'roberta.encoder.layer.1.attention.self.value.bias', 'roberta.encoder.layer.1.attention.self.value.weight', 'roberta.encoder.layer.1.intermediate.dense.bias', 'roberta.encoder.layer.1.intermediate.dense.weight', 'roberta.encoder.layer.1.output.LayerNorm.bias', 'roberta.encoder.layer.1.output.LayerNorm.weight', 'roberta.encoder.layer.1.output.dense.bias', 'roberta.encoder.layer.1.output.dense.weight', 'roberta.encoder.layer.10.attention.output.LayerNorm.bias', 'roberta.encoder.layer.10.attention.output.LayerNorm.weight', 'roberta.encoder.layer.10.attention.output.dense.bias', 'roberta.encoder.layer.10.attention.output.dense.weight', 'roberta.encoder.layer.10.attention.self.key.bias', 'roberta.encoder.layer.10.attention.self.key.weight', 'roberta.encoder.layer.10.attention.self.query.bias', 'roberta.encoder.layer.10.attention.self.query.weight', 'roberta.encoder.layer.10.attention.self.value.bias', 'roberta.encoder.layer.10.attention.self.value.weight', 'roberta.encoder.layer.10.intermediate.dense.bias', 'roberta.encoder.layer.10.intermediate.dense.weight', 'roberta.encoder.layer.10.output.LayerNorm.bias', 'roberta.encoder.layer.10.output.LayerNorm.weight', 'roberta.encoder.layer.10.output.dense.bias', 'roberta.encoder.layer.10.output.dense.weight', 'roberta.encoder.layer.11.attention.output.LayerNorm.bias', 'roberta.encoder.layer.11.attention.output.LayerNorm.weight', 'roberta.encoder.layer.11.attention.output.dense.bias', 'roberta.encoder.layer.11.attention.output.dense.weight', 'roberta.encoder.layer.11.attention.self.key.bias', 'roberta.encoder.layer.11.attention.self.key.weight', 'roberta.encoder.layer.11.attention.self.query.bias', 'roberta.encoder.layer.11.attention.self.query.weight', 'roberta.encoder.layer.11.attention.self.value.bias', 'roberta.encoder.layer.11.attention.self.value.weight', 'roberta.encoder.layer.11.intermediate.dense.bias', 'roberta.encoder.layer.11.intermediate.dense.weight', 'roberta.encoder.layer.11.output.LayerNorm.bias', 'roberta.encoder.layer.11.output.LayerNorm.weight', 'roberta.encoder.layer.11.output.dense.bias', 'roberta.encoder.layer.11.output.dense.weight', 'roberta.encoder.layer.2.attention.output.LayerNorm.bias', 'roberta. ...
# - This IS expected if you are initializing BertMultiTaskClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertMultiTaskClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertMultiTaskClassifier were not initialized from the model checkpoint at EMBEDDIA/litlat-bert and are newly initialized: ['embeddings.LayerNorm.bias', 'embeddings.LayerNorm.weight', 'embeddings.position_embeddings.weight', 'embeddings.token_type_embeddings.weight', 'embeddings.word_embeddings.weight', 'encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.layer.10.attention.output.LayerNorm.weight', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.10.attention.self.query.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.10.attention.self.value.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.attention.output.LayerNorm.bias', 'encoder.layer.11.attention.output.LayerNorm.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.11.attention.self.key.weight', 'encoder.layer.11.attention.self.query.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.LayerNorm.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.2.attention.output.LayerNorm.bias', 'encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.output.dense.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.2.attention.self.key.bias', 'encoder.layer.2.attention.self.key.weight', 'encoder.layer.2.attention.self.query.bias', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.3.attention.output.LayerNorm.bias ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# average_tokens_across_devices is True but world size is 1. Setting it to False automatically.
# ***** Running training *****
#   Num examples = 17,268
#   Num Epochs = 20
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10,800
#   Number of trainable parameters = 1,347,092
#     <div>
#
#       <progress value='10800' max='10800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10800/10800 54:31, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Score</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Roc Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.210400</td>
#       <td>0.852869</td>
#       <td>0.500506</td>
#       <td>0.667116</td>
#       <td>0.500506</td>
#       <td>1.000000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.144600</td>
#       <td>0.872835</td>
#       <td>0.512186</td>
#       <td>0.659346</td>
#       <td>0.507539</td>
#       <td>0.949516</td>
#       <td>0.511604</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.031800</td>
#       <td>0.847538</td>
#       <td>0.537150</td>
#       <td>0.591614</td>
#       <td>0.533579</td>
#       <td>0.695180</td>
#       <td>0.536819</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.973300</td>
#       <td>0.884035</td>
#       <td>0.545743</td>
#       <td>0.643319</td>
#       <td>0.531567</td>
#       <td>0.820743</td>
#       <td>0.545367</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.852600</td>
#       <td>0.850289</td>
#       <td>0.590463</td>
#       <td>0.654826</td>
#       <td>0.576193</td>
#       <td>0.781207</td>
#       <td>0.590178</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.610700</td>
#       <td>0.830706</td>
#       <td>0.620529</td>
#       <td>0.664061</td>
#       <td>0.606406</td>
#       <td>0.746390</td>
#       <td>0.620341</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.487200</td>
#       <td>0.793799</td>
#       <td>0.640310</td>
#       <td>0.663681</td>
#       <td>0.654158</td>
#       <td>0.712626</td>
#       <td>0.640137</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.373600</td>
#       <td>0.871089</td>
#       <td>0.628993</td>
#       <td>0.687211</td>
#       <td>0.593705</td>
#       <td>0.820341</td>
#       <td>0.628828</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.311300</td>
#       <td>0.847291</td>
#       <td>0.645053</td>
#       <td>0.709635</td>
#       <td>0.621004</td>
#       <td>0.851035</td>
#       <td>0.644889</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.260000</td>
#       <td>0.770401</td>
#       <td>0.666144</td>
#       <td>0.693449</td>
#       <td>0.649119</td>
#       <td>0.753331</td>
#       <td>0.666015</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.195800</td>
#       <td>0.767525</td>
#       <td>0.672170</td>
#       <td>0.704771</td>
#       <td>0.654931</td>
#       <td>0.775222</td>
#       <td>0.672019</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.089600</td>
#       <td>0.811823</td>
#       <td>0.678383</td>
#       <td>0.728365</td>
#       <td>0.641808</td>
#       <td>0.851007</td>
#       <td>0.678234</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.045700</td>
#       <td>0.750450</td>
#       <td>0.690521</td>
#       <td>0.718688</td>
#       <td>0.672633</td>
#       <td>0.777540</td>
#       <td>0.690435</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.003200</td>
#       <td>0.740304</td>
#       <td>0.698529</td>
#       <td>0.723476</td>
#       <td>0.679446</td>
#       <td>0.777631</td>
#       <td>0.698461</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.935600</td>
#       <td>0.750498</td>
#       <td>0.700129</td>
#       <td>0.730179</td>
#       <td>0.667533</td>
#       <td>0.807665</td>
#       <td>0.700007</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.950500</td>
#       <td>0.780895</td>
#       <td>0.697887</td>
#       <td>0.739699</td>
#       <td>0.661302</td>
#       <td>0.844637</td>
#       <td>0.697735</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.884000</td>
#       <td>0.746442</td>
#       <td>0.707592</td>
#       <td>0.738111</td>
#       <td>0.682707</td>
#       <td>0.813652</td>
#       <td>0.707450</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.857200</td>
#       <td>0.761697</td>
#       <td>0.706358</td>
#       <td>0.742565</td>
#       <td>0.670006</td>
#       <td>0.836382</td>
#       <td>0.706227</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.803900</td>
#       <td>0.754561</td>
#       <td>0.714359</td>
#       <td>0.747318</td>
#       <td>0.677145</td>
#       <td>0.835569</td>
#       <td>0.714262</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.813300</td>
#       <td>0.731874</td>
#       <td>0.716038</td>
#       <td>0.739263</td>
#       <td>0.689553</td>
#       <td>0.797952</td>
#       <td>0.715979</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-540
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-6916] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-1080
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-7280] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-1620
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-540] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-2160
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-1080] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-2700
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-1620] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-3240
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-2160] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-3780
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-2700] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-4320
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-3240] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-4860
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-3780] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-5400
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-4320] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-5940
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-4860] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-6480
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-5400] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-7020
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-5940] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-7560
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-6480] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-8100
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-7020] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-8640
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-7560] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-9180
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-8100] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-9720
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-8640] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-10260
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-9180] due to args.save_total_limit
#
# ***** Running Evaluation *****
#   Num examples = 2640
#   Batch size = 128
# Saving model checkpoint to outputs-train/litlatbert-lora-large/checkpoint-10800
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#
# Deleting older checkpoint [outputs-train/litlatbert-lora-large/checkpoint-9720] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from outputs-train/litlatbert-lora-large/checkpoint-10800 (score: 0.716038266996514).
#
# ***** Running Prediction *****
#   Num examples = 2642
#   Batch size = 128
# tokenizer config file saved in outputs/lith_classifier_litlatbert_lora_grouped_augmented/tokenizer_config.json
# Special tokens file saved in outputs/lith_classifier_litlatbert_lora_grouped_augmented/special_tokens_map.json
# sexuality
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       185
#            1       0.84      0.81      0.82       184
#
#     accuracy                           0.83       369
#    macro avg       0.83      0.83      0.83       369
# weighted avg       0.83      0.83      0.83       369
#
# religion
#               precision    recall  f1-score   support
#
#            0       0.71      0.51      0.59       183
#            1       0.62      0.79      0.69       183
#
#     accuracy                           0.65       366
#    macro avg       0.66      0.65      0.64       366
# weighted avg       0.66      0.65      0.64       366
#
# country
#               precision    recall  f1-score   support
#
#            0       0.77      0.68      0.72        93
#            1       0.71      0.80      0.75        94
#
#     accuracy                           0.74       187
#    macro avg       0.74      0.74      0.74       187
# weighted avg       0.74      0.74      0.74       187
#
# race
#               precision    recall  f1-score   support
#
#            0       0.69      0.52      0.59       360
#            1       0.62      0.76      0.68       361
#
#     accuracy                           0.64       721
#    macro avg       0.65      0.64      0.64       721
# weighted avg       0.65      0.64      0.64       721
#
# politics
#               precision    recall  f1-score   support
#
#            0       0.68      0.52      0.59       500
#            1       0.61      0.76      0.68       499
#
#     accuracy                           0.64       999
#    macro avg       0.65      0.64      0.63       999
# weighted avg       0.65      0.64      0.63       999
# loading configuration file config.json from cache at /home/paudan/.cache/huggingface/hub/models--EMBEDDIA--litlat-bert/snapshots/0ff2fcc527af01aa224c997f8159b6ede2fdd034/config.json
# Model config XLMRobertaConfig {
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.56.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 84201
# }
#         task  accuracy  f1_score  precision    recall     kappa   roc_auc
# 0  sexuality  0.826558  0.823204   0.837079  0.809783  0.653083  0.826513
# 1   religion  0.650273  0.693780   0.617021  0.792350  0.300546  0.650273
# 2    country  0.737968  0.753769   0.714286  0.797872  0.475591  0.737646
# 3       race  0.642164  0.680693   0.615213  0.761773  0.284089  0.641998
# 4   politics  0.637638  0.676208   0.610662  0.757515  0.275449  0.637758

# %%
print("Training finished:", datetime.now())
# Out:
# Training finished: 2026-05-16 01:58:42.590128
